# %% [markdown]
# # EDA — Telemetry Data
# Exploratory data analysis on simulated network telemetry.
# Will cover: distribution of latency/packet_loss, time-series seasonality,
# correlation between features, and baseline anomaly labelling.

# %% [markdown]
# # Isolation Forest Training
# Trains and evaluates the Scikit-learn Isolation Forest on telemetry snapshots.
# Covers: feature selection, contamination tuning, precision/recall evaluation,
# and model serialisation with joblib.

# %% [markdown]
# # LSTM Model Training
# Trains the PyTorch LSTM autoencoder on historical telemetry data.
# Covers: data loading, windowing, model definition, training loop,
# threshold selection, and TorchScript export for production inference.
